# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head(20)
# Out:
#                        Producto   Categoría del Producto     Precio  \
# 0             Asistente virtual             Electrónicos   164300.0
# 1               Mesa de comedor                  Muebles   192300.0
# 2                 Juego de mesa                 Juguetes   209600.0
# 3                    Microondas        Electrodomésticos   757500.0
# 4              Silla de oficina                  Muebles   335200.0
# 5       Bloques de construcción                 Juguetes    24200.0
# 6                   Muñeca bebé                 Juguetes    44200.0
# 7                  Lavavajillas        Electrodomésticos  1189700.0
# 8              Lavadora de ropa        Electrodomésticos  1518200.0
# 9     Carrito de control remoto                 Juguetes    75200.0
# 10                 Refrigerador        Electrodomésticos  2431300.0
# 11                 Lavavajillas        Electrodomésticos  1417100.0
# 12                  Auriculares             Electrónicos    91800.0
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
def ingresoTotalPorTienda(lista):
 return float(lista["Precio"].sum())

def ingresoTotal(lista1,lista2,lista3,lista4):
 return ingresoTotalPorTienda(lista1)+ingresoTotalPorTienda(lista2)+ingresoTotalPorTienda(lista3)+ingresoTotalPorTienda(lista4)

# %%
ingresoTotalPorTienda(tienda)
# Out:
# 1150880400.0

# %%
ingresoTotal(tienda,tienda2,tienda3,tienda4)
# Out:
# 4403619200.0

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# En este debes calcular la cantidad de productos vendidos por categoría en cada tienda. La idea es agrupar los datos por categoría y contar el número de ventas de cada tipo, mostrando las categorías más populares de cada tienda.

# %%
def ventasPorCategoriaPorTienda(tiendas):
 df = tiendas.copy()
 #df = df.drop(['Costo de envío', 'Precio',
 #     'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
 #     'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'], axis=1, inplace=False)  #Borramos columnas innesesarias

 df = df.iloc[:,[0,1]].copy()   #seleccionamos unicamente las dos columnas que nos interesa , la copiamos del df original y la guardamos en df
 df = df.rename(columns={'Producto': 'Cantidad de Productos Vendidos'}) #ronombramos la columna producto
 df = df.groupby(['Categoría del Producto']).count()#contamos todas las columnas
 df = df['Cantidad de Productos Vendidos'].sort_index(axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', sort_remaining=True, ignore_index=False, key=None)



 return df

# %%
ventasPorCategoriaPorTienda(tienda)
# Out:
# Categoría del Producto
# Artículos para el hogar    171
# Deportes y diversión       284
# Electrodomésticos          312
# Electrónicos               448
# Instrumentos musicales     182
# Juguetes                   324
# Libros                     173
# Muebles                    465
# Name: Cantidad de Productos Vendidos, dtype: int64

# %%
def maximaPorCategoriaPorTienda(tiendas):
  df = tiendas.copy()
  df = tiendas.copy()
  df = df.iloc[:,[0,1,2]].copy()
  df = df.groupby("Producto").max()
  return df

# %%
maximaPorCategoriaPorTienda(tienda)
# Out:
#                                 Precio
# Producto
# Ajedrez de madera              37500.0
# Armario                       524800.0
# Asistente virtual             297700.0
# Auriculares                   145800.0
# Auriculares con micrófono     257800.0
# Balón de baloncesto            73300.0
# Balón de voleibol              59800.0
# Batería                      1122500.0
# Bicicleta                     734800.0
# Bloques de construcción        44000.0
# Cama box                      741200.0
# Cama king                     972400.0
# Carrito de control remoto      88200.0
# Celular ABXY                 1335600.0
# Ciencia de datos con Python    71400.0
# Cubertería                     58600.0
# Cubo mágico 8x8                21700.0
# Cuerda para saltar             25700.0
# Dashboards con Power BI        44800.0
# Dinosaurio Rex                 22100.0
# Estufa                       1031600.0
# Guitarra acústica             441300.0
# Guitarra eléctrica            959100.0
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
df= tienda['Producto'].np.where(, x, y)

# %%
df

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
